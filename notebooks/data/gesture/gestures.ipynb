# %%
import pandas as pd

raw = pd.read_csv("a1_raw.csv")
va3 = pd.read_csv("a1_va3.csv")

# %%
raw.head(3)
# Out:
#         lhx       lhy       lhz       rhx       rhy       rhz        hx  \
# 0  5.347435  4.363681  1.501913  5.258967  4.319263  1.488703  5.037871
# 1  4.869622  4.254210  1.556133  5.240113  4.346338  1.554309  5.037610
# 2  5.357447  4.364039  1.500969  5.238928  4.347924  1.554150  5.037514
#
#          hy        hz        sx        sy        sz       lwx       lwy  \
# 0  1.618295  1.778350  5.062803  4.229656  1.772577  4.972902  4.301065
# 1  1.618370  1.778573  5.061430  4.228504  1.772859  4.974908  4.303656
# 2  1.618298  1.778774  5.059245  4.228004  1.773568  4.981612  4.305363
#
#         lwz       rwx       rwy       rwz  timestamp phase
# 0  1.564781  5.553945  4.370456  1.553521    5702026  Rest
# 1  1.565527  5.423875  4.303708  1.569942    5702058  Rest
# 2  1.563643  5.332170  4.438061  1.572841    5702089  Rest

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=raw)

# %%
# prompt: Using dataframe raw: show all recommended plots using plotly graph_objects. sign all traces with the respective name of the attribute they represent. add subplot titles for good understanding of what is being showed there. Please take into account that 1. lhx - Position of left hand (x coordinate)
#    2. lhy - Position of left hand (y coordinate)
#    3. lhz - Position of left hand (z coordinate)
#    4. rhx - Position of right hand (x coordinate)
#    5. rhy - Position of right hand (y coordinate)
#    6. rhz - Position of right hand (z coordinate)
#    7. hx - Position of head (x coordinate)
#    8. hy - Position of head  (y coordinate)
#    9. hz - Position of head  (z coordinate)
#    10. sx - Position of spine (x coordinate)
#    11. sy - Position of spine (y coordinate)
#    12. sz - Position of spine (z coordinate)
#    13. lwx - Position of left wrist (x coordinate)
#    14. lwy - Position of left wrist (y coordinate)
#    15. lwz - Position of left wrist (z coordinate)
#    16. rwx - Position of right wrist (x coordinate)
#    17. rwy - Position of right wrist (y coordinate)
#    18. rwz - Position of right wrist (z coordinate)
#  make subplot names with full names of these features

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create a list of columns to plot and their corresponding titles.
cols_to_plot = ['lhx', 'lhy', 'lhz', 'rhx', 'rhy', 'rhz', 'hx', 'hy', 'hz', 'sx', 'sy', 'sz', 'lwx', 'lwy', 'lwz', 'rwx', 'rwy', 'rwz']
titles = ['Position of Left Hand (x coordinate)', 'Position of Left Hand (y coordinate)', 'Position of Left Hand (z coordinate)',
          'Position of Right Hand (x coordinate)', 'Position of Right Hand (y coordinate)', 'Position of Right Hand (z coordinate)',
          'Position of Head (x coordinate)', 'Position of Head  (y coordinate)', 'Position of Head  (z coordinate)',
          'Position of Spine (x coordinate)', 'Position of Spine (y coordinate)', 'Position of Spine (z coordinate)',
          'Position of Left Wrist (x coordinate)', 'Position of Left Wrist (y coordinate)', 'Position of Left Wrist (z coordinate)',
          'Position of Right Wrist (x coordinate)', 'Position of Right Wrist (y coordinate)', 'Position of Right Wrist (z coordinate)']


# Create subplots with 6 rows and 3 columns.
fig = make_subplots(rows=6, cols=3, subplot_titles=titles)

# Add traces for each column to the corresponding subplot.
for i, col in enumerate(cols_to_plot):
    row = i // 3 + 1
    col_num = i % 3 + 1
    fig.add_trace(go.Scatter(x=raw['timestamp'], y=raw[col], mode='lines', name=col), row=row, col=col_num)

# Update layout with appropriate titles and labels.
fig.update_layout(height=1200, width=1200, title_text="Recommended Plots for Body Part Positions Over Time")

# Show the plot.
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: Can you do the same job as you did for the previous cell, but using the va3 dataframe. Take into account: 1. Vectorial velocity of left hand (x coordinate)
#    2. Vectorial velocity of left hand (y coordinate)
#    3. Vectorial velocity of left hand (z coordinate)
#    4. Vectorial velocity of right hand (x coordinate)
#    5. Vectorial velocity of right hand (y coordinate)
#    6. Vectorial velocity of right hand (z coordinate)
#    7. Vectorial velocity of left wrist (x coordinate)
#    8. Vectorial velocity of left wrist (y coordinate)
#    9. Vectorial velocity of left wrist (z coordinate)
#    10. Vectorial velocity of right wrist (x coordinate)
#    11. Vectorial velocity of right wrist (y coordinate)
#    12. Vectorial velocity of right wrist (z coordinate)
#    13. Vectorial acceleration of left hand (x coordinate)
#    14. Vectorial acceleration of left hand (y coordinate)
#    15. Vectorial acceleration of left hand (z coordinate)
#    16. Vectorial acceleration of right hand (x coordinate)
#    17. Vectorial acceleration of right hand (y coordinate)
#    18. Vectorial acceleration of right hand (z coordinate)
#    19. Vectorial acceleration of left wrist (x coordinate)
#    20. Vectorial acceleration of left wrist (y coordinate)
#    21. Vectorial acceleration of left wrist (z coordinate)
#    22. Vectorial acceleration of right wrist (x coordinate)
#    23. Vectorial acceleration of right wrist (y coordinate)
#    24. Vectorial acceleration of right wrist (z coordinate)
#    25. Scalar velocity of left hand
#    26. Scalar velocity of right hand
#    27. Scalar velocity of left wrist
#    28. Scalar velocity of right wrist
#    29. Scalar velocity of left hand
#    30. Scalar velocity of right hand
#    31. Scalar velocity of left wrist
#    32. Scalar velocity of right wrist
#    33. phase:
# 		-- D (rest position, from portuguese "descanso")
# 		-- P (preparation)
# 		-- S (stroke)
# 		-- H (hold)
# 		-- R (retraction)

import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Assuming 'va3' DataFrame is already loaded as in the previous code


cols_to_plot = [i for i in range(1,33)]
titles = [
    "Vectorial Velocity of Left Hand (x)", "Vectorial Velocity of Left Hand (y)", "Vectorial Velocity of Left Hand (z)",
    "Vectorial Velocity of Right Hand (x)", "Vectorial Velocity of Right Hand (y)", "Vectorial Velocity of Right Hand (z)",
    "Vectorial Velocity of Left Wrist (x)", "Vectorial Velocity of Left Wrist (y)", "Vectorial Velocity of Left Wrist (z)",
    "Vectorial Velocity of Right Wrist (x)", "Vectorial Velocity of Right Wrist (y)", "Vectorial Velocity of Right Wrist (z)",
    "Vectorial Acceleration of Left Hand (x)", "Vectorial Acceleration of Left Hand (y)", "Vectorial Acceleration of Left Hand (z)",
    "Vectorial Acceleration of Right Hand (x)", "Vectorial Acceleration of Right Hand (y)", "Vectorial Acceleration of Right Hand (z)",
    "Vectorial Acceleration of Left Wrist (x)", "Vectorial Acceleration of Left Wrist (y)", "Vectorial Acceleration of Left Wrist (z)",
    "Vectorial Acceleration of Right Wrist (x)", "Vectorial Acceleration of Right Wrist (y)", "Vectorial Acceleration of Right Wrist (z)",
    "Scalar Velocity of Left Hand", "Scalar Velocity of Right Hand", "Scalar Velocity of Left Wrist", "Scalar Velocity of Right Wrist",
    "Scalar Velocity of Left Hand 2", "Scalar Velocity of Right Hand 2", "Scalar Velocity of Left Wrist 2", "Scalar Velocity of Right Wrist 2"
]

# Create subplots (adjust rows and cols as needed)
fig = make_subplots(rows=8, cols=4, subplot_titles=titles)


for i, col in enumerate(cols_to_plot):
    row = i // 4 + 1
    col_num = i % 4 + 1
    fig.add_trace(go.Scatter(y=va3[str(col)], mode='lines', name=titles[i]), row=row, col=col_num)


fig.update_layout(height=2000, width=1500, title_text="Plots of VA3 Data")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: show me 2 subplots: the first one the phase attribute vs the timstamp of the raw dataframe and the second one the is the phase attribute vs just indices of phase.

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Assuming 'raw' DataFrame is already loaded

fig = make_subplots(rows=1, cols=2, subplot_titles=("a1_raw.csv", "a1_va3.csv"))

fig.add_trace(go.Scatter(x=raw['timestamp'], y=raw['phase'], mode='lines', name='Phase vs Timestamp'), row=1, col=1)
fig.add_trace(go.Scatter(x=raw.index, y=raw['phase'], mode='lines', name='Phase vs Index'), row=1, col=2)

fig.update_layout(height=600, width=1000, title_text="Target values")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
